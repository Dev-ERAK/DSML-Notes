# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("ola_driver_scaler.csv")
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19104 entries, 0 to 19103
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Unnamed: 0            19104 non-null  int64
#  1   MMM-YY                19104 non-null  object
#  2   Driver_ID             19104 non-null  int64
#  3   Age                   19043 non-null  float64
#  4   Gender                19052 non-null  float64
#  5   City                  19104 non-null  object
#  6   Education_Level       19104 non-null  int64
#  7   Income                19104 non-null  int64
#  8   Dateofjoining         19104 non-null  object
#  9   LastWorkingDate       1616 non-null   object
#  10  Joining Designation   19104 non-null  int64
#  11  Grade                 19104 non-null  int64
#  12  Total Business Value  19104 non-null  int64
#  13  Quarterly Rating      19104 non-null  int64
# dtypes: float64(2), int64(8), object(4)
# ...

# %%
data.head(10)
# Out:
#    Unnamed: 0    MMM-YY  Driver_ID   Age  Gender City  Education_Level
# 0           0  01/01/19          1  28.0     0.0  C23                2  \
# 1           1  02/01/19          1  28.0     0.0  C23                2
# 2           2  03/01/19          1  28.0     0.0  C23                2
# 3           3  11/01/20          2  31.0     0.0   C7                2
# 4           4  12/01/20          2  31.0     0.0   C7                2
# 5           5  12/01/19          4  43.0     0.0  C13                2
# 6           6  01/01/20          4  43.0     0.0  C13                2
# 7           7  02/01/20          4  43.0     0.0  C13                2
# 8           8  03/01/20          4  43.0     0.0  C13                2
# 9           9  04/01/20          4  43.0     0.0  C13                2
#
#    Income Dateofjoining LastWorkingDate  Joining Designation  Grade
# 0   57387      24/12/18             NaN                    1      1  \
# ...

# %%
data.describe()
# Out:
#          Unnamed: 0     Driver_ID           Age        Gender
# count  19104.000000  19104.000000  19043.000000  19052.000000  \
# mean    9551.500000   1415.591133     34.668435      0.418749
# std     5514.994107    810.705321      6.257912      0.493367
# min        0.000000      1.000000     21.000000      0.000000
# 25%     4775.750000    710.000000     30.000000      0.000000
# 50%     9551.500000   1417.000000     34.000000      0.000000
# 75%    14327.250000   2137.000000     39.000000      1.000000
# max    19103.000000   2788.000000     58.000000      1.000000
#
#        Education_Level         Income  Joining Designation         Grade
# count     19104.000000   19104.000000         19104.000000  19104.000000  \
# mean          1.021671   65652.025126             1.690536      2.252670
# std           0.800167   30914.515344             0.836984      1.026512
# min           0.000000   10747.000000             1.000000      1.000000
# ...

# %%
print("\nMissing values:")
print(data.isnull().sum())
# Out:
# Missing values:
# Unnamed: 0                  0
# MMM-YY                      0
# Driver_ID                   0
# Age                        61
# Gender                     52
# City                        0
# Education_Level             0
# Income                      0
# Dateofjoining               0
# LastWorkingDate         17488
# Joining Designation         0
# Grade                       0
# Total Business Value        0
# Quarterly Rating            0
# dtype: int64

# %%
data.drop(["Unnamed: 0"], axis=1, inplace=True)
data
# Out:
#          MMM-YY  Driver_ID   Age  Gender City  Education_Level  Income
# 0      01/01/19          1  28.0     0.0  C23                2   57387  \
# 1      02/01/19          1  28.0     0.0  C23                2   57387
# 2      03/01/19          1  28.0     0.0  C23                2   57387
# 3      11/01/20          2  31.0     0.0   C7                2   67016
# 4      12/01/20          2  31.0     0.0   C7                2   67016
# ...         ...        ...   ...     ...  ...              ...     ...
# 19099  08/01/20       2788  30.0     0.0  C27                2   70254
# 19100  09/01/20       2788  30.0     0.0  C27                2   70254
# 19101  10/01/20       2788  30.0     0.0  C27                2   70254
# 19102  11/01/20       2788  30.0     0.0  C27                2   70254
# 19103  12/01/20       2788  30.0     0.0  C27                2   70254
#
#       Dateofjoining LastWorkingDate  Joining Designation  Grade
# ...

# %%
data["LastWorkingDate"].value_counts().head(100)
# Out:
# LastWorkingDate
# 29/07/20    70
# 22/09/19    26
# 17/03/19    14
# 28/11/20    13
# 17/02/20    13
#             ..
# 06/07/20     5
# 24/03/20     5
# 15/09/20     5
# 06/03/19     5
# 01/05/19     5
# Name: count, Length: 100, dtype: int64

# %%
data["LastWorkingDate"].isnull()
# Out:
# 0         True
# 1         True
# 2        False
# 3         True
# 4         True
#          ...
# 19099     True
# 19100     True
# 19101     True
# 19102     True
# 19103     True
# Name: LastWorkingDate, Length: 19104, dtype: bool

# %%
data.loc[data.duplicated()]
# Out:
# Empty DataFrame
# Columns: [MMM-YY, Driver_ID, Age, Gender, City, Education_Level, Income, Dateofjoining, LastWorkingDate, Joining Designation, Grade, Total Business Value, Quarterly Rating]
# Index: []

# %%
# Check for duplicate trip uuid
data.loc[data.duplicated(subset=['Driver_ID'])].head()
# Out:
#      MMM-YY  Driver_ID   Age  Gender City  Education_Level  Income
# 1  02/01/19          1  28.0     0.0  C23                2   57387  \
# 2  03/01/19          1  28.0     0.0  C23                2   57387
# 4  12/01/20          2  31.0     0.0   C7                2   67016
# 6  01/01/20          4  43.0     0.0  C13                2   65603
# 7  02/01/20          4  43.0     0.0  C13                2   65603
#
#   Dateofjoining LastWorkingDate  Joining Designation  Grade
# 1      24/12/18             NaN                    1      1  \
# 2      24/12/18        03/11/19                    1      1
# 4      11/06/20             NaN                    2      2
# 6      12/07/19             NaN                    2      2
# 7      12/07/19             NaN                    2      2
#
#    Total Business Value  Quarterly Rating
# 1               -665480                 2
# 2                     0                 2
# 4                     0                 1
# ...

# %%
# Explore the distribution of categorical variables
sns.countplot(x='Gender', data=data)
plt.title('Gender')
plt.show()

# %%
data['MMM-YY'] = pd.to_datetime(data['MMM-YY'])
data
# Out:
# C:\Users\Aman Kumar\AppData\Local\Temp\ipykernel_21200\3004307827.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   data['MMM-YY'] = pd.to_datetime(data['MMM-YY'])
#           MMM-YY  Driver_ID   Age  Gender City  Education_Level  Income
# 0     2019-01-01          1  28.0     0.0  C23                2   57387  \
# 1     2019-02-01          1  28.0     0.0  C23                2   57387
# 2     2019-03-01          1  28.0     0.0  C23                2   57387
# 3     2020-11-01          2  31.0     0.0   C7                2   67016
# 4     2020-12-01          2  31.0     0.0   C7                2   67016
# ...          ...        ...   ...     ...  ...              ...     ...
# 19099 2020-08-01       2788  30.0     0.0  C27                2   70254
# 19100 2020-09-01       2788  30.0     0.0  C27                2   70254
# ...

# %%
data['Dateofjoining'] = pd.to_datetime(data['Dateofjoining'])
data
# Out:
#           MMM-YY  Driver_ID   Age  Gender City  Education_Level  Income
# 0     2019-01-01          1  28.0     0.0  C23                2   57387  \
# 1     2019-02-01          1  28.0     0.0  C23                2   57387
# 2     2019-03-01          1  28.0     0.0  C23                2   57387
# 3     2020-11-01          2  31.0     0.0   C7                2   67016
# 4     2020-12-01          2  31.0     0.0   C7                2   67016
# ...          ...        ...   ...     ...  ...              ...     ...
# 19099 2020-08-01       2788  30.0     0.0  C27                2   70254
# 19100 2020-09-01       2788  30.0     0.0  C27                2   70254
# 19101 2020-10-01       2788  30.0     0.0  C27                2   70254
# 19102 2020-11-01       2788  30.0     0.0  C27                2   70254
# 19103 2020-12-01       2788  30.0     0.0  C27                2   70254
#
#       Dateofjoining LastWorkingDate  Joining Designation  Grade
# ...

# %%
data['LastWorkingDate'] = pd.to_datetime(data['LastWorkingDate'])
data
# Out:
# C:\Users\Aman Kumar\AppData\Local\Temp\ipykernel_21200\1495528837.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   data['LastWorkingDate'] = pd.to_datetime(data['LastWorkingDate'])
#           MMM-YY  Driver_ID   Age  Gender City  Education_Level  Income
# 0     2019-01-01          1  28.0     0.0  C23                2   57387  \
# 1     2019-02-01          1  28.0     0.0  C23                2   57387
# 2     2019-03-01          1  28.0     0.0  C23                2   57387
# 3     2020-11-01          2  31.0     0.0   C7                2   67016
# 4     2020-12-01          2  31.0     0.0   C7                2   67016
# ...          ...        ...   ...     ...  ...              ...     ...
# 19099 2020-08-01       2788  30.0     0.0  C27                2   70254
# 19100 2020-09-01       2788  30.0     0.0  C27                2   70254
# ...

# %%
data.groupby(['Driver_ID'])["Income"].count().sort_values()
# Out:
# Driver_ID
# 1978     1
# 148      1
# 540      1
# 2281     1
# 561      1
#         ..
# 1446    24
# 2027    24
# 2028    24
# 2494    24
# 2259    24
# Name: Income, Length: 2381, dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19104 entries, 0 to 19103
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   MMM-YY                19104 non-null  datetime64[ns]
#  1   Driver_ID             19104 non-null  int64
#  2   Age                   19043 non-null  float64
#  3   Gender                19052 non-null  float64
#  4   City                  19104 non-null  object
#  5   Education_Level       19104 non-null  int64
#  6   Income                19104 non-null  int64
#  7   Dateofjoining         19104 non-null  datetime64[ns]
#  8   LastWorkingDate       1616 non-null   datetime64[ns]
#  9   Joining Designation   19104 non-null  int64
#  10  Grade                 19104 non-null  int64
#  11  Total Business Value  19104 non-null  int64
#  12  Quarterly Rating      19104 non-null  int64
# dtypes: datetime64[ns](3), float64(2), int64(7), object(1)
# memory usage: 1.9+ MB

# %%
data[data["Driver_ID"] == 1]
# Out:
#       MMM-YY  Driver_ID   Age  Gender City  Education_Level  Income
# 0 2019-01-01          1  28.0     0.0  C23                2   57387  \
# 1 2019-02-01          1  28.0     0.0  C23                2   57387
# 2 2019-03-01          1  28.0     0.0  C23                2   57387
#
#   Dateofjoining LastWorkingDate  Joining Designation  Grade
# 0    2018-12-24             NaN                    1      1  \
# 1    2018-12-24             NaN                    1      1
# 2    2018-12-24        03/11/19                    1      1
#
#    Total Business Value  Quarterly Rating
# 0               2381060                 2
# 1               -665480                 2
# 2                     0                 2

# %%
data[data["Gender"].isnull()]
# Out:
#           MMM-YY  Driver_ID   Age  Gender City  Education_Level  Income
# 240   2019-02-01         43  27.0     NaN  C15                0   12906  \
# 258   2019-02-01         49  21.0     NaN  C20                0   53039
# 264   2019-08-01         49  21.0     NaN  C20                0   53039
# 466   2019-08-01         68  31.0     NaN  C29                0   79288
# 820   2019-02-01        116  21.0     NaN  C11                0   16477
# 859   2019-11-01        119  31.0     NaN  C29                1   71000
# 1514  2020-12-01        225  32.0     NaN  C14                0   44792
# 1892  2019-08-01        296  31.0     NaN  C20                1   65094
# 2277  2019-02-01        354  31.0     NaN  C11                0   60555
# 2359  2020-03-01        365  24.0     NaN  C22                0   44740
# 2683  2019-06-01        407  40.0     NaN  C13                1   58207
# 2932  2020-03-01        439  27.0     NaN   C3                1   60246
# ...

# %%
data[(data["Driver_ID"] == 49)]
# Out:
#         MMM-YY  Driver_ID   Age  Gender City  Education_Level  Income
# 257 2019-01-01         49  21.0     0.0  C20                0   53039  \
# 258 2019-02-01         49  21.0     NaN  C20                0   53039
# 259 2019-03-01         49  21.0     0.0  C20                0   53039
# 260 2019-04-01         49  21.0     0.0  C20                0   53039
# 261 2019-05-01         49   NaN     0.0  C20                0   53039
# 262 2019-06-01         49  21.0     0.0  C20                0   53039
# 263 2019-07-01         49  21.0     0.0  C20                0   53039
# 264 2019-08-01         49  21.0     NaN  C20                0   53039
# 265 2019-09-01         49  21.0     0.0  C20                0   53039
# 266 2019-10-01         49  21.0     0.0  C20                0   53039
# 267 2019-11-01         49   NaN     0.0  C20                0   53039
# 268 2019-12-01         49  21.0     0.0  C20                0   53039
# ...

# %%
def update_gender(data):
    # create an object for KNNImputer
    imputer = KNNImputer(n_neighbors=2)
    #print(data["Driver_ID"])
    print("Before Driver AGE")
    print(data["Age"])
    new_data = imputer.fit_transform(data[["Gender","Age"]])
    driver_data = pd.DataFrame(new_data, columns=["Gender","Age"])
    print(" Driver Data after imputer")
    print(driver_data)
    print("After imputer Driver AGE")
    print(driver_data["Age"])
    
    data["Gender"] = driver_data["Gender"]
    print(data["Age"])
    data["Age"] = driver_data["Age"]
    print(data["Age"])
    data["Age"] = new_data[:,1]
    print(data["Age"])
    ##return data

# %%
data.groupby(['Driver_ID']).apply(update_gender)
# Out:
# Before Driver AGE
# 0    28.0
# 1    28.0
# 2    28.0
# Name: Age, dtype: float64
#  Driver Data after imputer
#    Gender   Age
# 0     0.0  28.0
# 1     0.0  28.0
# 2     0.0  28.0
# After imputer Driver AGE
# 0    28.0
# 1    28.0
# 2    28.0
# Name: Age, dtype: float64
# 0    28.0
# 1    28.0
# 2    28.0
# Name: Age, dtype: float64
# 0    28.0
# 1    28.0
# 2    28.0
# Name: Age, dtype: float64
# Before Driver AGE
# 3    31.0
# 4    31.0
# Name: Age, dtype: float64
#  Driver Data after imputer
#    Gender   Age
# 0     0.0  31.0
# 1     0.0  31.0
# After imputer Driver AGE
# 0    31.0
# 1    31.0
# Name: Age, dtype: float64
# 3    31.0
# 4    31.0
# Name: Age, dtype: float64
# 3   NaN
# 4   NaN
# Name: Age, dtype: float64
# Before Driver AGE
# 5    43.0
# 6    43.0
# 7    43.0
# 8    43.0
# 9    43.0
# Name: Age, dtype: float64
#  Driver Data after imputer
#    Gender   Age
# 0     0.0  43.0
# 1     0.0  43.0
# 2     0.0  43.0
# 3     0.0  43.0
# 4     0.0  43.0
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19104 entries, 0 to 19103
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   MMM-YY                19104 non-null  datetime64[ns]
#  1   Driver_ID             19104 non-null  int64
#  2   Age                   19043 non-null  float64
#  3   Gender                19052 non-null  float64
#  4   City                  19104 non-null  object
#  5   Education_Level       19104 non-null  int64
#  6   Income                19104 non-null  int64
#  7   Dateofjoining         19104 non-null  datetime64[ns]
#  8   LastWorkingDate       1616 non-null   datetime64[ns]
#  9   Joining Designation   19104 non-null  int64
#  10  Grade                 19104 non-null  int64
#  11  Total Business Value  19104 non-null  int64
#  12  Quarterly Rating      19104 non-null  int64
# dtypes: datetime64[ns](3), float64(2), int64(7), object(1)
# memory usage: 1.9+ MB

# %%
data[["Driver_ID","Age"]]
# Out:
#        Driver_ID   Age
# 0              1  28.0
# 1              1  28.0
# 2              1  28.0
# 3              2  31.0
# 4              2  31.0
# ...          ...   ...
# 19099       2788  30.0
# 19100       2788  30.0
# 19101       2788  30.0
# 19102       2788  30.0
# 19103       2788  30.0
#
# [19104 rows x 2 columns]

# %%
numerical_cols = ['Age', 'Income', 'Total Business Value']
plt.figure(figsize=(12, 4))
for i, col in enumerate(numerical_cols, 1):
    plt.subplot(1, len(numerical_cols), i)
    sns.histplot(data[col], kde=True)
    plt.title(col)
plt.tight_layout()
plt.show()

# %%
# Visualize other relationships using scatter plots, box plots, etc.
# For example:
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Age', y='Income', data=data, hue='Gender')
plt.title('Age vs Income')
plt.show()

# %%
from sklearn.impute import KNNImputer
 
 
# create dataset for marks of a student
dict = {'Maths':[80, 90, np.nan, 95], 
        'Chemistry': [60, 65, 56, np.nan], 
        'Physics':[np.nan, 57, 80, 78],
       'Biology' : [78,83,67,np.nan]}
 
# creating a data frame from the list 
Before_imputation = pd.DataFrame(dict)
#print dataset before imputation
print("Data Before performing imputation\n",Before_imputation)
 
# create an object for KNNImputer
imputer = KNNImputer(n_neighbors=1)
After_imputation = imputer.fit_transform(Before_imputation)
# print dataset after performing the operation
print("\n\nAfter performing imputation\n",After_imputation)

# create an object for KNNImputer
imputer = KNNImputer(n_neighbors=3)
After_imputation = imputer.fit_transform(Before_imputation)
# print dataset after performing the operation
print("\n\nAfter performing imputation\n",After_imputation)
# Out:
# Data Before performing imputation
#     Maths  Chemistry  Physics  Biology
# 0   80.0       60.0      NaN     78.0
# 1   90.0       65.0     57.0     83.0
# 2    NaN       56.0     80.0     67.0
# 3   95.0        NaN     78.0      NaN
#
#
# After performing imputation
#  [[80. 60. 57. 78.]
#  [90. 65. 57. 83.]
#  [95. 56. 80. 67.]
#  [95. 56. 78. 67.]]
#
#
# After performing imputation
#  [[80.         60.         71.66666667 78.        ]
#  [90.         65.         57.         83.        ]
#  [88.33333333 56.         80.         67.        ]
#  [95.         60.33333333 78.         76.        ]]
